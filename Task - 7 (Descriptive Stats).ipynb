# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             5000              8000                  3             2000
# 1             6000              7000                  2             3000
# 2            10000              4500                  2                0
# 3            10000              2000                  1                0
# 4            12500             12000                  2             3000
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0             64200           Under-Graduate                      1
# 1             79920               Illiterate                      1
# 2            112800           Under-Graduate                      1
# 3             97200               Illiterate                      1
# 4            147000                 Graduate                      1

# %%
df.shape
# Out:
# (50, 7)

# %% [markdown]
# ### MEAN
#
# Mean is the total of the sum of all values in a collection of numbers divided by the number of numbers in a collection.
#
# <h2><center> $ \mu = \frac {x_1 + x_2 + x_3 +....+x_n}{n} $ </center></h2> where n is number of observations.
#
# The formula can also be written as
#
# <h2><center> $\mu = \frac{\sum_{i=1}^{n} x_i}{n} $ </center></h2>

# %%
mean_Mthly_HH_Income = df['Mthly_HH_Income'].mean()
mean_Mthly_HH_Expense = df['Mthly_HH_Expense'].mean()
mean_No_of_Fly_Members = df['No_of_Fly_Members'].mean()
mean_Emi_or_Rent_Amt = df['Emi_or_Rent_Amt'].mean()
mean_Annual_HH_Income = df['Annual_HH_Income'].mean()

# %%
print("Mean of Mthly_HH_Income" ,mean_Mthly_HH_Income)
print("Mean of Mthly_HH_Expense" ,mean_Mthly_HH_Expense)
print("Mean of No_of_Fly_Members" ,mean_No_of_Fly_Members)
print("Mean of Emi_or_Rent_Amt" ,mean_Emi_or_Rent_Amt)
print("Mean of Annual_HH_Income" ,mean_Annual_HH_Income)
# Out:
# Mean of Mthly_HH_Income 41558.0
# Mean of Mthly_HH_Expense 18818.0
# Mean of No_of_Fly_Members 4.06
# Mean of Emi_or_Rent_Amt 3060.0
# Mean of Annual_HH_Income 490019.04

# %%
df['Highest_Qualified_Member'].dtype.name
# Out:
# 'object'

# %%
for cols in df.columns:
    if df[cols].dtype.name == 'object':
        continue
    else:
        total =0
        avg =0
        for i in range(df.shape[0]):
            total += float(df[cols][i])
        avg = total/df.shape[0]
        print("Mean of "+cols+" : " + str(avg))
# Out:
# Mean of Mthly_HH_Income : 41558.0
# Mean of Mthly_HH_Expense : 18818.0
# Mean of No_of_Fly_Members : 4.06
# Mean of Emi_or_Rent_Amt : 3060.0
# Mean of Annual_HH_Income : 490019.04
# Mean of No_of_Earning_Members : 1.46

# %% [markdown]
# ### Median
#
# Median is a statistical measure that determines the middle value of a dataset listed in ascending order (i.e., from smallest to largest value). The measure divides the lower half from the higher half of the dataset.
#
# 1. First, arrange the number of observation in an ascending orders
# 2. If the number of the observations (n) is odd:
#     1. The median is the value at position  ($ \frac {n+1}{2}$)
# 3. If the number of the observation (n) is even:
#     1. Find the value at position ($ \frac{n}{2}$)
#     2. Find the value at position ($\frac{n+1}{2}$)
#     3. Find the averge of the two values to get the mean

# %%
median_Mthly_HH_Income = df['Mthly_HH_Income'].median()
median_Mthly_HH_Expense = df['Mthly_HH_Expense'].median()
median_No_of_Fly_Members = df['No_of_Fly_Members'].median()
median_Emi_or_Rent_Amt = df['Emi_or_Rent_Amt'].median()
median_Annual_HH_Income = df['Annual_HH_Income'].median()

# %%
print("Median of Mthly_HH_Income" ,median_Mthly_HH_Income)
print("Median of Mthly_HH_Expense" ,median_Mthly_HH_Expense)
print("Median of No_of_Fly_Members" ,median_No_of_Fly_Members)
print("Median of Emi_or_Rent_Amt" ,median_Emi_or_Rent_Amt)
print("Median of Annual_HH_Income" ,median_Annual_HH_Income)
# Out:
# Median of Mthly_HH_Income 35000.0
# Median of Mthly_HH_Expense 15500.0
# Median of No_of_Fly_Members 4.0
# Median of Emi_or_Rent_Amt 0.0
# Median of Annual_HH_Income 447420.0

# %%
for cols in df.columns:
    if df[cols].dtype.name == 'object':
        continue
    else:
        n = df.shape[0]
        sorted_df = sorted(df[cols])
        if n % 2 == 0:
            median1 = sorted_df[n//2]
            median2 = sorted_df[n//2 - 1]
            median = (median1 + median2)/2
        else:
            median = sorted_df[n//2]
        print("Median of "+ cols+ " : " + str(median))
# Out:
# Median of Mthly_HH_Income : 35000.0
# Median of Mthly_HH_Expense : 15500.0
# Median of No_of_Fly_Members : 4.0
# Median of Emi_or_Rent_Amt : 0.0
# Median of Annual_HH_Income : 447420.0
# Median of No_of_Earning_Members : 1.0

# %% [markdown]
# ### Mode
#
# Mode is the most frequently occuring value. To find the mode, order the numbers lowest to highest and see which number appears the most often.
#
# Example : 9,3,4,6,3,1,6,3
# -  ordered : 1,3,3,3,4,6,6,9
# -  Here, the mode is <b> 3 </b>

# %%
mode_Mthly_HH_Income = df['Mthly_HH_Income'].mode()
mode_Mthly_HH_Expense = df['Mthly_HH_Expense'].mode()
mode_No_of_Fly_Members = df['No_of_Fly_Members'].mode()
mode_Emi_or_Rent_Amt = df['Emi_or_Rent_Amt'].mode()
mode_Annual_HH_Income = df['Annual_HH_Income'].mode()
mode_No_of_Earning_Members = df['No_of_Earning_Members'].mode()

# %%
print("mode of Mthly_HH_Income" ,mode_Mthly_HH_Income)
print("mode of Mthly_HH_Expense" ,mode_Mthly_HH_Expense)
print("mode of No_of_Fly_Members" ,mode_No_of_Fly_Members)
print("mode of Emi_or_Rent_Amt" ,mode_Emi_or_Rent_Amt)
print("mode of Annual_HH_Income" ,mode_Annual_HH_Income)
print("mode of No_of_Earning_Members" ,mode_No_of_Earning_Members)
# Out:
# mode of Mthly_HH_Income 0    45000
# dtype: int64
# mode of Mthly_HH_Expense 0    25000
# dtype: int64
# mode of No_of_Fly_Members 0    4
# dtype: int64
# mode of Emi_or_Rent_Amt 0    0
# dtype: int64
# mode of Annual_HH_Income 0    590400
# dtype: int64
# mode of No_of_Earning_Members 0    1
# dtype: int64

# %%
from collections import Counter
for cols in df.columns:
    if df[cols].dtype.name == 'object':
        continue
    else:
        n = df.shape[0]
        sorted_df = sorted(df[cols])
        count = Counter(sorted_df)
        get_dict = dict(count)
        mode = [key for key,value in get_dict.items() if value == max(list(count.values()))]
        if(len(mode)==n):
            continue
        else:
            print("Mode of "+ cols+ " : " + str(mode[0]))
# Out:
# Mode of Mthly_HH_Income : 45000
# Mode of Mthly_HH_Expense : 25000
# Mode of No_of_Fly_Members : 4
# Mode of Emi_or_Rent_Amt : 0
# Mode of Annual_HH_Income : 590400
# Mode of No_of_Earning_Members : 1

# %% [markdown]
# ### Variance
#
# Variance tells the <b>degree of spread</b> in a data set. The more spread the data, the larger the variance is in relation to the mean.
#
# It is calculated by taking the average of squared deviations from the mean.
#
# <h3><center> $\sigma^2 = \frac{\sum_{i=1}^{n} (x_i - \mu)^2}{N}  $ </center><h3>
# <h4>$\sigma^2$ = variance
#
# $ x_i $ = observation
#
# $ \mu $ = mean
#
# N = number of observations </h4>

# %%
var_Mthly_HH_Income = np.var(df['Mthly_HH_Income'])
var_Mthly_HH_Expense = np.var(df['Mthly_HH_Expense'])
var_No_of_Fly_Members = np.var(df['No_of_Fly_Members'])
var_Emi_or_Rent_Amt = np.var(df['Emi_or_Rent_Amt'])
var_Annual_HH_Income = np.var(df['Annual_HH_Income'])
var_No_of_Earning_Members = np.var(df['No_of_Earning_Members'])

# %%
print("variance in Mthly_HH_Income" ,var_Mthly_HH_Income)
print("variance in Mthly_HH_Expense" ,var_Mthly_HH_Expense)
print("variance in No_of_Fly_Members" ,var_No_of_Fly_Members)
print("variance in Emi_or_Rent_Amt" ,var_Emi_or_Rent_Amt)
print("variance in Annual_HH_Income" ,var_Annual_HH_Income)
print("variance in No_of_Earning_Members" ,var_No_of_Earning_Members)
# Out:
# variance in Mthly_HH_Income 667478836.0
# variance in Mthly_HH_Expense 143249876.0
# variance in No_of_Fly_Members 2.2564
# variance in Emi_or_Rent_Amt 38176400.0
# variance in Annual_HH_Income 100437186889.95831
# variance in No_of_Earning_Members 0.5284

# %%
for cols in df.columns:
    if df[cols].dtype.name == 'object':
        continue
    else:
        total =0
        avg =0
        var_num = 0
        var= 0
        n= df.shape[0]
        for i in range(n):
            total += float(df[cols][i])
        avg = total/df.shape[0]
        for i in range(n):
            var_num += (df[cols][i]-avg)**2
        var = var_num / n
        print("Variance of "+ cols+ " : " + str(var))
# Out:
# Variance of Mthly_HH_Income : 667478836.0
# Variance of Mthly_HH_Expense : 143249876.0
# Variance of No_of_Fly_Members : 2.2564
# Variance of Emi_or_Rent_Amt : 38176400.0
# Variance of Annual_HH_Income : 100437186889.95831
# Variance of No_of_Earning_Members : 0.5284

# %% [markdown]
# ### Standard Deviation
#
# The Standard Deviation is a measure of how spread out numbers are. It is the square root of the Variance
#
#
# <h3><center> $\sigma = \sqrt \frac{\sum_{i=1}^{n} (x_i - \mu)}{N}$ </center></h3>
#
# $ \sigma $ = standard deviation
#
# N = number of observations
#
# $ x_i $ = = observation i
#
# $\mu $  = mean
#
# ![title](std.jpg)

# %%
std_Mthly_HH_Income = np.std(df['Mthly_HH_Income'])
std_Mthly_HH_Expense = np.std(df['Mthly_HH_Expense'])
std_No_of_Fly_Members = np.std(df['No_of_Fly_Members'])
std_Emi_or_Rent_Amt = np.std(df['Emi_or_Rent_Amt'])
std_Annual_HH_Income = np.std(df['Annual_HH_Income'])
std_No_of_Earning_Members = np.std(df['No_of_Earning_Members'])

# %%
print("Standard deviation in Mthly_HH_Income" ,std_Mthly_HH_Income)
print("Standard deviation in Mthly_HH_Expense" ,std_Mthly_HH_Expense)
print("Standard deviation in No_of_Fly_Members" ,std_No_of_Fly_Members)
print("Standard deviation in Emi_or_Rent_Amt" ,std_Emi_or_Rent_Amt)
print("Standard deviation in Annual_HH_Income" ,std_Annual_HH_Income)
print("Standard deviation in No_of_Earning_Members ",std_No_of_Earning_Members )
# Out:
# Standard deviation in Mthly_HH_Income 25835.611779092826
# Standard deviation in Mthly_HH_Expense 11968.704023410388
# Standard deviation in No_of_Fly_Members 1.502131818450032
# Standard deviation in Emi_or_Rent_Amt 6178.705366013175
# Standard deviation in Annual_HH_Income 316918.26531451027
# Standard deviation in No_of_Earning_Members  0.72691127381545

# %%
import math
for cols in df.columns:
    if df[cols].dtype.name == 'object':
        continue
    else:
        total =0
        avg =0
        var_num = 0
        var= 0
        n= df.shape[0]
        for i in range(n):
            total += float(df[cols][i])
        avg = total/df.shape[0]
        for i in range(n):
            var_num += (df[cols][i]-avg)**2
        std = math.sqrt(var_num / n)
        print("Variance of "+ cols+ " : " + str(std))
# Out:
# Variance of Mthly_HH_Income : 25835.611779092826
# Variance of Mthly_HH_Expense : 11968.704023410388
# Variance of No_of_Fly_Members : 1.502131818450032
# Variance of Emi_or_Rent_Amt : 6178.705366013175
# Variance of Annual_HH_Income : 316918.26531451027
# Variance of No_of_Earning_Members : 0.72691127381545

# %% [markdown]
# ### Correlation
#
# Correlation refers to a process for establishing the relationships between two variables
# -  Methods of correlation summarize the relationship between two variables in a single number called the correlation coefficient.
# -  The correlation coefficient is usually represented using the symbol r, and it ranges from -1 to +1.
# -  A correlation coefficient quite close to 0, but either positive or negative, implies little or no relationship between the two variables.
#
# #### Positive Correlation
# -  A correlation coefficient close to plus 1 means a positive relationship between the two variables, with increases in one of the variables being associated with increases in the other variable.
#
# #### Negative Correlation
# -  A correlation coefficient close to -1 indicates a negative relationship between two variables, with an increase in one of the variables being associated with a decrease in the other variable.
#
# #### No Correlation
# -  When there is no linear dependence or no relation between the two variables.
#
# ![title](corr.png)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(df)

# %%
##Correlation coefficient
for cols in df.columns:
    if df[cols].dtype.name == 'object':
        continue
    else:
        for cols2 in df.columns:
            if df[cols2].dtype.name == 'object':
                continue
            if cols==cols2:
                continue
            else:
                my_rho = np.corrcoef(df[cols], df[cols2])
                print("Correlation coefficient of "+ cols +" and " + cols2 + " is "+ str(my_rho[0][1]))
# Out:
# Correlation coefficient of Mthly_HH_Income and Mthly_HH_Expense is 0.6492152549316462
# Correlation coefficient of Mthly_HH_Income and No_of_Fly_Members is 0.4483173135943264
# Correlation coefficient of Mthly_HH_Income and Emi_or_Rent_Amt is 0.03697611093890591
# Correlation coefficient of Mthly_HH_Income and Annual_HH_Income is 0.970315416660371
# Correlation coefficient of Mthly_HH_Income and No_of_Earning_Members is 0.34788345602238385
# Correlation coefficient of Mthly_HH_Expense and Mthly_HH_Income is 0.6492152549316462
# Correlation coefficient of Mthly_HH_Expense and No_of_Fly_Members is 0.6397015597607348
# Correlation coefficient of Mthly_HH_Expense and Emi_or_Rent_Amt is 0.4052802691623041
# Correlation coefficient of Mthly_HH_Expense and Annual_HH_Income is 0.5912216295468026
# Correlation coefficient of Mthly_HH_Expense and No_of_Earning_Members is 0.31191517457975393
# Correlation coefficient of No_of_Fly_Members and Mthly_HH_Income is 0.44831731359432636
# ...

# %% [markdown]
# ### Normal Distribution
#
# The normal distribution is the most important probability distribution in statistics because it fits many natural phenomena. The normal distribution is a probability function that describes how the values of a variable are distributed.
# - It is a symmetric distribution where most of the observations cluster around the central peak and the probabilities for values further away from the mean taper off equally in both directions.
# - Extreme values in both tails of the distribution are similarly unlikely.
#
# The general form of its probability density function is
# <h2><center> f(x) = $\frac{1}{\sigma\sqrt{2\pi}}
#   \exp\left( -\frac{1}{2}\left(\frac{x-\mu}{\sigma}\right)^{\!2}\,\right)$</center></h2>
#
# ![title](normal_dist.png)
#
# <b> Characteristic properties of Normal Distribution </b>
#
# -  They’re all symmetric. The normal distribution cannot model skewed distributions.
# -  The mean, median, and mode are all equal.
# -  Half of the population is less than the mean and half is greater than the mean.
# -  The Empirical Rule allows you to determine the proportion of values that fall within certain distances from the mean.
#
# <b> The Empirical Rule for the Normal Distribution </b>
#
# When you have normally distributed data, the standard deviation becomes particularly valuable. You can use it to determine the proportion of the values that fall within a specified number of standard deviations from the mean.
#
# -  For example, in a normal distribution, 68% of the observations fall within +/- 1 standard deviation from the mean.
# -  This property is part of the Empirical Rule, which describes the percentage of the data that fall within specific numbers of standard deviations from the mean for bell-shaped curves.
#
# ![title](ND.png)
#
# <b> Standard Normal Distribution </b>
#
# The standard normal distribution is a special case of the normal distribution where the mean is zero and the standard deviation is 1. This distribution is also known as the <b>Z-distribution.</b>
#
# ![title](standard_normal_distribution.png)
#
# -  A value on the standard normal distribution is known as a standard score or a Z-score.
# -  A standard score represents the number of standard deviations above or below the mean that a specific observation falls.
#
# Z-score is given by $ Z = \frac{X-\mu}{\sigma} $

# %%
x = df['Mthly_HH_Income']
def normal_dist(x , mean , sd):
    prob_density = (np.pi*sd) * np.exp(-0.5*((x-mean)/sd)**2)
    return prob_density
mean = np.mean(x)
std = np.std(x)
pdf = normal_dist(x,mean,std)
plt.plot(x,pdf , color = 'red')
plt.title('Mthly_HH_Income')
# Out:
# Text(0.5, 1.0, 'Mthly_HH_Income')

# %%
x = df['Annual_HH_Income']
def normal_dist(x , mean , sd):
    prob_density = (np.pi*sd) * np.exp(-0.5*((x-mean)/sd)**2)
    return prob_density
mean = np.mean(x)
std = np.std(x)
pdf = normal_dist(x,mean,std)
plt.plot(x,pdf , color = 'red')
plt.title('Annual_HH_Income')
# Out:
# Text(0.5, 1.0, 'Annual_HH_Income')

# %%
sns.displot(df['Mthly_HH_Income'],kde=True)
sns.displot(df['Annual_HH_Income'],kde=True)  #here it is positively skewed

# %% [markdown]
# ### Skewed Distribution
#
# If one tail is longer than another, the distribution is skewed. These distributions are sometimes called asymmetric or asymmetrical distributions as they don’t show any kind of symmetry.
#
# #### Positively Skewed Normal Distribution
#
# A Positively Skewed distribution has a long right tail. Positively Skewed distributions are also called right-skewed distributions. That’s because there is a long tail in the positive direction on the number line. The mean is also to the right of the peak.
#
# #### Negatively Skewed Normal Distribution
#
# A negatively-skewed distribution has a long left tail. Negatively-skewed distributions are also called left-skewed distributions. That’s because there is a long tail in the negative direction on the number line. The mean is also to the left of the peak.
#
#
# ![title](skew.png)

# %% [markdown]
# ### Effect on Mean, Median and Mode due to Skewness
#
# -  Real life distributions are usually skewed. Too much skewness, and many statistical techniques don’t work.
#
# -  In a Normal Distribution, mean = mode = median
#
# -  If mean > median > mode, the skewness is <b>positive</b>
#
# - If mean < median <mode, the skewness is <b>negative</b>
#
# - The median is less affected by outliers and skewed data than the mean, and is usually the preferred measure of central tendency when the distribution is not symmetrical.
#
# - Outliers are extreme, or a typical data value(s) that are notably different from the rest of the data.
#
# - It is important to detect outliers within a distribution, because they can alter the results of the data analysis.
#
# - The mean is more sensitive to the existence of outliers than the median or mode.

# %% [markdown]
# ### Q-Q (Quantile - Quantile)Plot
#
# In statistics, a Q–Q (quantile-quantile) plot is a probability plot, which is a graphical method for comparing two probability distributions by plotting their quantiles against each other.
#
# -  First, the set of intervals for the quantiles is chosen.
# -  A point (x, y) on the plot corresponds to one of the quantiles of the second distribution (y-coordinate) plotted against the same quantile of the first distribution (x-coordinate).
#
# ![title](qq.png)
#
#
#
#
# -  A Q–Q plot is used to compare the shapes of distributions, providing a graphical view of how properties such as location, scale, and skewness are similar or different in the two distributions
#
#
# -  A Q–Q plot is generally a more powerful approach to do this than the common technique of comparing histograms of the two samples, but requires more skill to interpret.

# %%
from scipy import stats
import matplotlib.pyplot as plt
x = stats.t.rvs(df['Mthly_HH_Income'])

res = stats.probplot(x, plot=plt)

# %%
y = stats.t.rvs(df['Annual_HH_Income'])

res = stats.probplot(y, plot=plt)

# %% [markdown]
# ### Box Cox
#
# A Box Cox transformation is a transformation of a non-normal dependent variables into a normal shape.
# If the data isn’t normal, applying a Box-Cox means that you are able to run a broader number of tests.
#
# #### Running the Test
#
# -  Box Cox transformation is an exponent, lambda ($\lambda$), which varies from -5 to 5.
# -  All values of $\lambda$ are considered and the optimal value for your data is selected; The “optimal value” is the one which results in the best approximation of a normal distribution curve. The transformation of Y has the form:
# <center> $ y(\lambda) =  \begin{cases}
#     \frac{y^\lambda-1}{\lambda},& \text{if } \lambda \neq 0\\
#     log y, & \text{if} \lambda = 0
# \end{cases} $ </center>
#
# -  This test only works for positive data. However, Box and Cox did propose a second formula that can be used for negative y-values:
#
# <center> $ y(\lambda) =  \begin{cases}
#     \frac{(y+\lambda_2)^\left(\lambda_1 \right)  - 1}{\lambda_1},& \text{if } \lambda_1 \neq 0\\
#     log (y+\lambda_2), & \text{if} \lambda_1 = 0
# \end{cases} $ </center>

# %%
original_data = df['Mthly_HH_Income']
  
fitted_data, fitted_lambda = stats.boxcox(original_data)

# %%
fig, ax = plt.subplots(1, 2)
sns.distplot(original_data, hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2}, 
            label = "Non-Normal", color ="green", ax = ax[0])
  
sns.distplot(fitted_data, hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2}, 
            label = "Normal", color ="green", ax = ax[1])
# Out:
# C:\Users\shiri\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\shiri\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
original_data = df['No_of_Earning_Members']
  
fitted_data, fitted_lambda = stats.boxcox(original_data)

# %%
fig, ax = plt.subplots(1, 2)
sns.distplot(original_data, hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2}, 
            label = "Non-Normal", color ="green", ax = ax[0])
  
sns.distplot(fitted_data, hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2}, 
            label = "Normal", color ="green", ax = ax[1])
# Out:
# C:\Users\shiri\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\shiri\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>
